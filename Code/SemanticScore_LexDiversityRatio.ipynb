# %% [markdown]
# Lexical Diversity is the ratio of unique words to total number of words in the review.

# %%
#Import Libraries
import pandas as pd
import numpy as np

# %%
#Read dataset obtained from preprocessing steps and after calculation of subjectivity score, flesch index, polarity score, entropy score, dale chall index, helpful ratio
toy_data=pd.read_csv("C:/Users/khurd/Documents/255/Project/Toys_and_Games.csv")
toy_data
# Out:
#               asin helpful  overall  \
# 0        439893577  [1, 1]        4
# 1        439893577  [1, 1]        5
# 2        439893577  [0, 0]        5
# 3        439893577  [1, 1]        4
# 4        439893577  [0, 0]        3
# ...            ...     ...      ...
# 162962  B00LBI9BKA  [0, 0]        5
# 162963  B00LBI9BKA  [1, 1]        5
# 162964  B00LBI9BKA  [0, 0]        5
# 162965  B00LBI9BKA  [0, 0]        5
# 162966  B00LBI9BKA  [0, 0]        4
#
#                                                reviewText   reviewTime  \
# 0       Love the magnet easel... great for moving to d...  03 28, 2014
# 1       Both sides are magnetic.  A real plus when you...  01 28, 2013
# 2       Bought one a few years ago for my daughter and...   02 8, 2014
# 3       I have a stainless steel refrigerator therefor...   05 5, 2014
# 4       this is a nice magnetic board for the kids to ...  05 16, 2013
# ...                                                   ...          ...
# ...

# %%
#Add new column 'Lex Diversity Ratio' to the dataframe
toy_data['Lex Diversity Ratio']=0

# %%
#Having a look at first 5 rows of dataframe and checking if the new column is added
toy_data.head(5)
# Out:
#         asin helpful  overall  \
# 0  439893577  [1, 1]        4
# 1  439893577  [1, 1]        5
# 2  439893577  [0, 0]        5
# 3  439893577  [1, 1]        4
# 4  439893577  [0, 0]        3
#
#                                           reviewText   reviewTime  \
# 0  Love the magnet easel... great for moving to d...  03 28, 2014
# 1  Both sides are magnetic.  A real plus when you...  01 28, 2013
# 2  Bought one a few years ago for my daughter and...   02 8, 2014
# 3  I have a stainless steel refrigerator therefor...   05 5, 2014
# 4  this is a nice magnetic board for the kids to ...  05 16, 2013
#
#        reviewerID                            PreProcessed_reviewText  \
# 0   A8R62G708TSCM  love the magnet easel great for moving to diff...
# 1  A21KH420DK0ICA  both sides are magnetic  a real plus when your...
# 2   AR29QK6HPFYZ4  bought one a few years ago for my daughter and...
# 3   ACCH8EOML6FN5  i have a stainless steel refrigerator therefor...
# ...

# %%
#Computing Lex Diversity Ratio for each preprocessed review test using nltk library
from nltk import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
import nltk
import nltk.data

# %%
raw_data=open('C:/Users/khurd/Documents/255/Project/Toys_and_Games.csv').read()
raw_data[0:500]
# Out:
# 'asin,helpful,overall,reviewText,reviewTime,reviewerID,PreProcessed_reviewText,subjectivity_score,flesch_index,polarity_score,entropy_score,DaleChall_Index,helpful_ratio,Lex Diversity Ratio\n439893577,"[1, 1]",4,Love the magnet easel... great for moving to different areas... Wish it had some sort of non skid pad on bottom though...,"03 28, 2014",A8R62G708TSCM,love the magnet easel great for moving to different areas wish it had some sort of non skid pad on bottom though,0.65,8.3,0.4333333333333333'

# %%
with open('C:/Users/khurd/Documents/255/Project/Toys_and_Games.csv', 'r') as reader:
    moby_raw = reader.read()

# %%
moby_tokens = nltk.word_tokenize(moby_raw)
text = nltk.Text(moby_tokens)
moby_series = pd.Series(moby_tokens)

# %%
#Function to Count the total number of words
def countToken():
     
    return len(moby_tokens)

MOBY_TOKEN_COUNT = countToken()
print("Dataset has {:,} words.".format(
     MOBY_TOKEN_COUNT))
# Out:
# Dataset has 39,167,008 words.

# %%
#Function to count total number of unique words
def uniqueToken():
    
    return len(set(nltk.word_tokenize(moby_raw)))

MOBY_UNIQUE_COUNT = uniqueToken()
print("Dataset has {:,} unique words.".format(
    MOBY_UNIQUE_COUNT))
# Out:
# Dataset has 550,673 unique words.

# %%
#Function for lexical diversity
def lexical_diversity(tokens):
   
    return len(set(tokens))/float(len(tokens))

# %%
def outputLexDiversity():
    
    return lexical_diversity(moby_tokens)

output = outputLexDiversity()
print("Lexical Diversity of Dataset: {:.2f}".format(output))
# Out:
# Lexical Diversity of Dataset: 0.01

# %%
#Calculation the lexDiversity for review text
toy_data['Lex Diversity Ratio']=toy_data['PreProcessed_reviewText'].apply(lexical_diversity)

# %%
#Lex Diversities
toy_data['Lex Diversity Ratio']
# Out:
# 0         0.187500
# 1         0.056650
# 2         0.143836
# 3         0.095833
# 4         0.114583
#             ...
# 162962    0.194444
# 162963    0.045075
# 162964    0.031332
# 162965    0.095436
# 162966    0.052288
# Name: Lex Diversity Ratio, Length: 162967, dtype: float64

# %%
toy_data.head(100)
# Out:
#           asin helpful  overall  \
# 0    439893577  [1, 1]        4
# 1    439893577  [1, 1]        5
# 2    439893577  [0, 0]        5
# 3    439893577  [1, 1]        4
# 4    439893577  [0, 0]        3
# ..         ...     ...      ...
# 95  073533417X  [1, 1]        5
# 96  073533417X  [1, 1]        5
# 97  073533417X  [1, 1]        5
# 98  073533417X  [3, 3]        3
# 99  073533417X  [0, 0]        4
#
#                                            reviewText   reviewTime  \
# 0   Love the magnet easel... great for moving to d...  03 28, 2014
# 1   Both sides are magnetic.  A real plus when you...  01 28, 2013
# 2   Bought one a few years ago for my daughter and...   02 8, 2014
# 3   I have a stainless steel refrigerator therefor...   05 5, 2014
# 4   this is a nice magnetic board for the kids to ...  05 16, 2013
# ..                                                ...          ...
# 95  Jumbo puzzles are the way to go for young ones...   01 8, 2013
# ...

# %%
#Adding the Lex Diversity Ratios to the original csv
toy_data.to_csv('C:/Users/khurd/Documents/255/Project/Toys_and_Games.csv',index=False)

# %%
#Checking if the new computed values are added to the dataframe
df=pd.read_csv("C:/Users/khurd/Documents/255/Project/Toys_and_Games.csv")
df
# Out:
#               asin helpful  overall  \
# 0        439893577  [1, 1]        4
# 1        439893577  [1, 1]        5
# 2        439893577  [0, 0]        5
# 3        439893577  [1, 1]        4
# 4        439893577  [0, 0]        3
# ...            ...     ...      ...
# 162962  B00LBI9BKA  [0, 0]        5
# 162963  B00LBI9BKA  [1, 1]        5
# 162964  B00LBI9BKA  [0, 0]        5
# 162965  B00LBI9BKA  [0, 0]        5
# 162966  B00LBI9BKA  [0, 0]        4
#
#                                                reviewText   reviewTime  \
# 0       Love the magnet easel... great for moving to d...  03 28, 2014
# 1       Both sides are magnetic.  A real plus when you...  01 28, 2013
# 2       Bought one a few years ago for my daughter and...   02 8, 2014
# 3       I have a stainless steel refrigerator therefor...   05 5, 2014
# 4       this is a nice magnetic board for the kids to ...  05 16, 2013
# ...                                                   ...          ...
# ...
